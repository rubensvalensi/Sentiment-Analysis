# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words("english")
from nltk.tokenize import TweetTokenizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/alberttamman/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Load Data**

# %%
df = pd.read_csv('trainingandtestdata/training.1600000.processed.noemoticon.csv', encoding='latin-1', header = None, names=['sentiment', 'id', 'date', 'flag', 'user', 'tweet'])

# %%
from sklearn.utils import shuffle
df = shuffle(df)

df = df.head(100000)
df
# Out:
#          sentiment          id                          date      flag  \
# 676615           0  2248449502  Fri Jun 19 20:38:34 PDT 2009  NO_QUERY
# 529875           0  2195676258  Tue Jun 16 11:27:12 PDT 2009  NO_QUERY
# 1087153          4  1969397156  Fri May 29 23:54:38 PDT 2009  NO_QUERY
# 1434265          4  2060598791  Sat Jun 06 19:12:31 PDT 2009  NO_QUERY
# 1332787          4  2016281000  Wed Jun 03 06:30:10 PDT 2009  NO_QUERY
# ...            ...         ...                           ...       ...
# 250090           0  1983131006  Sun May 31 12:33:48 PDT 2009  NO_QUERY
# 1515925          4  2175658181  Mon Jun 15 01:37:04 PDT 2009  NO_QUERY
# 1070072          4  1966041577  Fri May 29 17:00:54 PDT 2009  NO_QUERY
# 984048           4  1834349005  Mon May 18 02:35:42 PDT 2009  NO_QUERY
# 424927           0  2063213465  Sun Jun 07 01:47:08 PDT 2009  NO_QUERY
#
#                    user                                              tweet
# 676615   woodlandalyssa          monster headache  hope i can sleep it off
# 529875    VeronicanLife  I'm very sad because my fedex tracking number ...
# 1087153      scrapchick  @cameron_crazy Are you beginning to nest w/ al...
# 1434265    bridgetmarym                           Hanging out with my mom
# 1332787    glitterngold  Good Morning tweets! New day and new outlook o...
# ...                 ...                                                ...
# 250090      o0wowzers0o  So it's true? Ms. Snyder did die? Wow, that's ...
# 1515925      ChelseaO92                                     is in my pj's
# 1070072          xxanna  @skateramps sounds good  im up for some JB Hi-...
# 984048              3CB  @shiskydadon oops, i think i DMed half and the...
# 424927    CourtneyKrebs  someone get me out of here PLEASE...i will pay...
#
# [100000 rows x 6 columns]

# %%
from sklearn.model_selection import StratifiedKFold
y = df['sentiment']
feats = [col for col in df.columns if col!= "sentiment"]
X = df[feats]
skf = StratifiedKFold(n_splits=5, random_state=12345, shuffle=True)
train_index, test_index = list(skf.split(X, y))[0]
df_test, df_train = df.iloc[test_index], df.iloc[train_index]

# %% [markdown]
# **Clean Data**
# 1. Remove Duplicate Rows
# 2. Remove Columns we wont use
# 3. Format Target column (sentiment) into 0/1

# %%
df_train = df_train.drop_duplicates(subset=['id'], keep='first')
df_train = df_train.drop_duplicates(subset=['id'], keep='first')

df_train.drop(columns=['id', 'flag', 'user'], inplace=True)
df_test.drop(columns=['id', 'flag', 'user'], inplace=True)
# Out:
# /Users/alberttamman/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4312: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_train["sentiment"] = df_train["sentiment"].apply(lambda s: 1 if s!=0 else s)
df_test["sentiment"] = df_test["sentiment"].apply(lambda s: 1 if s!=0 else s)
# Out:
# /Users/alberttamman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_test
# Out:
#          sentiment                          date  \
# 1434265          1  Sat Jun 06 19:12:31 PDT 2009
# 31019            0  Mon Apr 20 00:51:50 PDT 2009
# 738279           0  Sun Jun 21 06:34:07 PDT 2009
# 1251324          1  Mon Jun 01 15:09:07 PDT 2009
# 195104           0  Sat May 30 03:50:20 PDT 2009
# ...            ...                           ...
# 1166434          1  Sun May 31 05:05:05 PDT 2009
# 1545469          1  Mon Jun 15 12:45:19 PDT 2009
# 767716           0  Tue Jun 23 14:24:13 PDT 2009
# 907792           1  Mon May 04 07:14:33 PDT 2009
# 362354           0  Fri Jun 05 13:32:55 PDT 2009
#
#                                                      tweet
# 1434265                           Hanging out with my mom
# 31019              Thinks he needs someone to cuddle with
# 738279   Happy Father's Day.Sad day i have a wake to go...
# 1251324  hot hot hotttttttttttttttttttttttttttttttttttt...
# 195104   @littlemunchkin she's too small to come out ye...
# ...                                                    ...
# 1166434  3 liters of Pepsi light later I am almost awak...
# 1545469                           @MileyMelody  You sing?
# 767716   My daughter has nits  and it's her primary sch...
# 907792   @ThrivingIvory the next single is &quot;Hey La...
# 362354   is up again early with the kids, i wouldn't mi...
#
# [20000 rows x 3 columns]

# %% [markdown]
# **Feature Engineering**
#
# - Note: These new columns were not used in baseline model but might be useful later

# %%
import re
df_train["hashtags"] = df_train["tweet"].apply(lambda x: ",".join(tag for tag in list(re.findall(r"#(\w+)", x))))
df_test["hashtags"] = df_test["tweet"].apply(lambda x: ",".join(tag for tag in list(re.findall(r"#(\w+)", x))))
df_train["hashtag_count"] = df_train["hashtags"].apply(lambda h: len(h.split(',')) if len(h)>0 else 0)
df_test["hashtag_count"] = df_test["hashtags"].apply(lambda h: len(h.split(',')) if len(h) >0 else 0)
# Out:
# /Users/alberttamman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/alberttamman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# **Preprocessing**
# 1. Lower-case letters
# 2. Remove stop words
# 3. Tokenize using twitter tokenizer and lemmatize
# 4. Remove punctuation

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub('@[A-Za-z0–9]+', ' ', text)
    text = re.sub('#', ' ', text)
    text = re.sub('https?:\/\/\S+', ' ', text)
    return text

# %%
df_train["tweet"] = df_train["tweet"].apply(lambda x: clean_text(x))
df_test["tweet"] = df_test["tweet"].apply(lambda x: clean_text(x))
# Out:
# /Users/alberttamman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def remove_stop_words(s):
    new_sent = ""
    for word in s.split():
        if word not in stop_words:
            new_sent += " " + word
    return new_sent

df_train["tweet"] = df_train["tweet"].apply(lambda s: remove_stop_words(s))

# %%
df_test["tweet"] = df_test["tweet"].apply(lambda s: remove_stop_words(s))
# Out:
# /Users/alberttamman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def lemmatize_tokenize(tweet):
    lemmatizer = nltk.stem.WordNetLemmatizer()
    tokenizer = TweetTokenizer()
    new_t = []
    for word in tokenizer.tokenize(tweet):
        new_word = re.sub(r'[^\w\s]', '', (word))
        if new_word != '':
            new_t.append(lemmatizer.lemmatize(new_word)) 
    return " ".join(new_t)

# %%
df_train["tweet"] = df_train["tweet"].apply(lambda t: lemmatize_tokenize(t))
df_test["tweet"] = df_test["tweet"].apply(lambda t: lemmatize_tokenize(t))
# Out:
# /Users/alberttamman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# **Modelling with Word2Vec & RNN**

# %%
from gensim.models import Word2Vec

documents = [text.split() for text in df_train.tweet]
size = 200
model = Word2Vec(size=size, window=7, min_count=10, workers=4)
model.build_vocab(documents)

# %%
model.train(documents, total_examples=len(documents), epochs=20)
# Out:
# (9809436, 12308620)

# %%
model.wv.most_similar("hate")
# Out:
# [('fuck', 0.4357706606388092),
#  ('ugh', 0.4192028343677521),
#  ('stupid', 0.39120057225227356),
#  ('killing', 0.3799291253089905),
#  ('ignored', 0.37581247091293335),
#  ('kill', 0.37091881036758423),
#  ('ruin', 0.36644476652145386),
#  ('freaking', 0.36063283681869507),
#  ('screw', 0.3564320206642151),
#  ('stressing', 0.3537784218788147)]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts(df_train.tweet)

# %%
from tensorflow.keras.preprocessing import sequence 

sequences_train = tokenizer.texts_to_sequences(df_train.tweet)
sequences_test = tokenizer.texts_to_sequences(df_test.tweet)
X_train_seq = sequence.pad_sequences(sequences_train, maxlen=100, value=0)
X_test_seq = sequence.pad_sequences(sequences_test, maxlen=100, value=0)

# %%
y_train = df_train["sentiment"]
y_test = df_test["sentiment"]

# %%
w_index = tokenizer.word_index

vocab_size = len(w_index) + 1

# %%
embedding_m = np.zeros((vocab_size, size))

# %%
for word, idx in list(w_index.items()):
    if word in list(model.wv.vocab.keys()):
        embedding_m[idx] = model.wv[word]

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Embedding, LSTM, GRU,Bidirectional, Dropout, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.initializers import Constant

# %%
nn_model = Sequential()

# %%
emb_layer = Embedding(vocab_size, 200, weights=[embedding_m], input_length=100, trainable=False)
nn_model.add(emb_layer)
nn_model.add(Bidirectional(LSTM(100, dropout=0.2, recurrent_dropout=0.2)))
nn_model.add(Dense(1, activation='sigmoid'))

# %%
nn_model.compile(loss='binary_crossentropy',optimizer="adam",metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

nn_model.summary()
callbacks = [EarlyStopping(monitor='val_accuracy', patience=0)]
nn_model.fit(X_train_seq, y_train, batch_size=128, epochs=12, validation_split=0.2, callbacks=callbacks)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 200)          9596400
# _________________________________________________________________
# bidirectional (Bidirectional (None, 200)               240800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 9,837,401
# Trainable params: 241,001
# Non-trainable params: 9,596,400
# _________________________________________________________________
# Epoch 1/12
#  26/500 [>.............................] - ETA: 3:48 - loss: 0.6494 - accuracy: 0.6359
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-db4f6aecf0a1> in <module>
#       3 nn_model.summary()
#       4 callbacks = [EarlyStopping(monitor='val_accuracy', patience=0)]
# ----> 5 nn_model.fit(X_train_seq, y_train, batch_size=128, epochs=12, validation_split=0.2, callbacks=callbacks)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
from nltk.probability import FreqDist

# %%
' '.join([i for i in df_train["tweet"]]).split()
# Out:
# ['monster',
#  'headache',
#  'hope',
#  'sleep',
#  'im',
#  'sad',
#  'fedex',
#  'tracking',
#  'number',
#  'working',
#  '2',
#  'damn',
#  'day',
#  'cry',
#  'new',
#  'laptop',
#  '_crazy',
#  'beginning',
#  'nest',
#  'w',
#  'cleaning',
#  'think',
#  'so',
#  'time',
#  'wanted',
#  'pull',
#  'appliance',
#  'clean',
#  'behind',
#  'good',
#  'morning',
#  'tweet',
#  'new',
#  'day',
#  'new',
#  'outlook',
#  'thing',
#  'life',
#  'too',
#  'flail',
#  'cant',
#  'january',
#  'yet',
#  'brian',
#  'austin',
#  'green',
#  'hott',
#  'whatever',
#  'happened',
#  'original',
#  '90210',
#  'miss',
#  'day',
#  'lack',
#  'communication',
#  'somehow',
#  'im',
#  'confident',
#  'physic',
#  'psych',
#  'king',
#  'island',
#  'today',
#  'felt',
#  'good',
#  'sleep',
#  'gettin',
#  'foil',
#  'put',
#  'on',
#  'cant',
#  'beleev',
#  '2',
#  'month',
#  'left',
#  'love',
#  'goin',
#  'fast',
#  'sorry',
#  'caused',
#  'inconv',
#  'tc',
#  'bye',
#  'srikanth',
#  'wishing',
#  'imc',
#  '09',
#  'best',
#  'summer',
#  'residency',
#  '1',
#  'whoohoooo',
#  'day',
#  'start',
#  'working',
#  'again',
#  'lol',
#  'report',
#  'thursday',
#  'laying',
#  'sun',
#  'day',
#  'line',
#  'sure',
#  'fudge',
#  'get',
#  'brace',
#  'school',
#  'start',
#  'haha',
#  'love',
#  'macie',
#  'cute',
#  'omg',
#  'im',
#  'tired',
#  'singing',
#  'day',
#  'today',
#  'happy',
#  'done',
#  'so',
#  'im',
#  'happy',
#  'well',
#  'much',
#  'same',
#  'see',
#  'shall',
#  'collaborate',
#  'exhausted',
#  'took',
#  'mostly',
#  'everything',
#  'room',
#  'unscrewed',
#  'light',
#  'taped',
#  'outlet',
#  'started',
#  'painting',
#  'access',
#  'real',
#  'fun',
#  'tomorrow',
#  'possible',
#  'phone',
#  'may',
#  'defective',
#  'gone',
#  'lena',
#  'how',
#  'boring',
#  'but',
#  'may',
#  'see',
#  'favorite',
#  'aunt',
#  'uncle',
#  'chewauhah',
#  'jos',
#  'mac',
#  'cheese',
#  'good',
#  'nom',
#  'nom',
#  'nom',
#  'get',
#  'bill',
#  'lazy',
#  'money',
#  'pay',
#  'it',
#  'monday',
#  'morning',
#  'weighin',
#  '178',
#  '1',
#  'pound',
#  'dang',
#  'yummy',
#  'hamburger',
#  'trailer',
#  'trash',
#  'party',
#  'pushed',
#  'over',
#  'back',
#  'tweetie',
#  'sry',
#  'cheating',
#  'love',
#  'too',
#  'yeah',
#  'wish',
#  'could',
#  'mom',
#  'sick',
#  'lukeys',
#  'feeling',
#  'sick',
#  'u',
#  'next',
#  'week',
#  'kate',
#  'died',
#  'instead',
#  'hmm',
#  'twitteriffic',
#  'still',
#  'working',
#  'okay',
#  'twitter',
#  'dont',
#  'upload',
#  'background',
#  'reckon',
#  'tattoo',
#  'made',
#  'miami',
#  'yaay',
#  'love',
#  'locked',
#  'outta',
#  'house',
#  '1111',
#  'yeah',
#  'thats',
#  'problem',
#  'first',
#  'flight',
#  'delayed',
#  'find',
#  'get',
#  'phoenix',
#  'seattle',
#  'barely',
#  'layover',
#  'business',
#  'travel',
#  'yay',
#  'best',
#  'chicken',
#  'cutlet',
#  'ever',
#  'beautiful',
#  'loving',
#  'family',
#  'thanks',
#  'sharing',
#  'special',
#  'moment',
#  'u',
#  'w00t',
#  'coffee',
#  'im',
#  'fueled',
#  'mcds',
#  'hazlenut',
#  'iced',
#  'coffee',
#  'today',
#  'drive',
#  '7',
#  'hr',
#  'home',
#  'room',
#  'empty',
#  'im',
#  'going',
#  'sort',
#  'miss',
#  'little',
#  'bit',
#  'lot',
#  'because',
#  'well',
#  'meant',
#  'like',
#  'hall',
#  'did',
#  'cloud',
#  'twitter',
#  'dust',
#  'im',
#  'invisble',
#  'yo',
#  'superstar',
#  'simple',
#  'person',
#  'love',
#  'peroson',
#  '4christ',
#  'think',
#  'so',
#  'goodapparently',
#  'meant',
#  'sleep',
#  'good',
#  'yeah',
#  'feel',
#  'really',
#  'strange',
#  'kind',
#  'surreal',
#  'im',
#  'really',
#  'excited',
#  'journey',
#  'right',
#  'now',
#  'youre',
#  'reason',
#  'letting',
#  'go',
#  'alright',
#  'picked',
#  'everyone',
#  'finally',
#  'hit',
#  'road',
#  'haaad',
#  'best',
#  'sat',
#  'night',
#  'long',
#  'time',
#  'love',
#  'steph',
#  'im',
#  'sorry',
#  'walked',
#  'away',
#  'fro',
#  '25',
#  'second',
#  'if',
#  'there',
#  'wed',
#  'brawwwwlin',
#  'loving',
#  'schoooool',
#  'lot',
#  'sleepp',
#  'nothing',
#  'one',
#  'week',
#  'left',
#  'chemistry',
#  '102',
#  'next',
#  'weekk',
#  'ohhh',
#  'nooo',
#  'joy',
#  'joy',
#  'another',
#  'late',
#  'night',
#  'enjoy',
#  'skip',
#  'congrats',
#  'godbless',
#  'what',
#  'bad',
#  'day',
#  'what',
#  'id',
#  'help',
#  'dont',
#  'know',
#  'how',
#  'sorry',
#  'promise',
#  'ill',
#  'productive',
#  'take',
#  'nap',
#  'head',
#  'feel',
#  'like',
#  'balloon',
#  'pop',
#  'always',
#  'put',
#  'coffee',
#  'irel',
#  'google',
#  'that',
#  'coffee',
#  'cake',
#  'walnut',
#  'go',
#  'well',
#  'too',
#  'df',
#  'dubb',
#  'long',
#  'time',
#  'wait',
#  'plane',
#  'much',
#  'appreciated',
#  '_eric',
#  'least',
#  'could',
#  'since',
#  'grow',
#  'wanna',
#  'draw',
#  'pretty',
#  'picture',
#  'like',
#  'you',
#  'visit',
#  'geek',
#  'squad',
#  'laptop',
#  'live',
#  'high',
#  'live',
#  'mighty',
#  'live',
#  'righteously',
#  'takin',
#  'easy',
#  'enjoy',
#  'sunday',
#  'boyfriend',
#  'house',
#  'soooo',
#  'want',
#  'read',
#  's',
#  'miki',
#  'fall',
#  'summer',
#  'lol',
#  'made',
#  'think',
#  'again',
#  'lol',
#  'back',
#  'writing',
#  'hometown',
#  'astronaut',
#  'chris',
#  'cassidy',
#  'head',
#  'i',
#  'june',
#  '13',
#  'go',
#  'maine',
#  'nasa',
#  'spaceshuttle',
#  '1029',
#  'concert',
#  'missed',
#  'it',
#  'im',
#  'really',
#  'sad',
#  'becuz',
#  'trouble',
#  'stuff',
#  'im',
#  'cry',
#  'sigh',
#  'cry',
#  'lot',
#  'though',
#  'one',
#  'eva',
#  'lol',
#  'im',
#  'mad',
#  'bored',
#  'got',
#  'back',
#  'first',
#  'swim',
#  'lesson',
#  'season',
#  'many',
#  'many',
#  'go',
#  'better',
#  'all',
#  'currently',
#  'rained',
#  'on',
#  'thats',
#  'ikr',
#  'sorry',
#  'sha',
#  'fault',
#  'make',
#  'sooooo',
#  'dang',
#  'easy',
#  'loooove',
#  'him',
#  'really',
#  'hope',
#  'read',
#  'letter',
#  'hi',
#  'staci',
#  'indeed',
#  'back',
#  'fine',
#  'busy',
#  'you',
#  'business',
#  'seem',
#  'go',
#  'good',
#  'not',
#  'undergrad',
#  'degree',
#  'get',
#  'mngr',
#  'position',
#  'best',
#  'buy',
#  'moes',
#  '_tinks',
#  'aha',
#  'yes',
#  'woken',
#  'getting',
#  'ready',
#  'lucky',
#  'you',
#  'he',
#  'rival',
#  'jackson',
#  'whoa',
#  'good',
#  'shit',
#  'want',
#  'go',
#  'back',
#  'sleep',
#  'early',
#  'up',
#  'help',
#  'please',
#  'vote',
#  '4',
#  '4',
#  'b96',
#  'summer',
#  'bash',
#  'hometown',
#  'chitown',
#  'im',
#  'finalist',
#  'thanks',
#  'thanx',
#  'effing',
#  'day',
#  'up',
#  'lol',
#  'j',
#  'k',
#  'good',
#  'meerning',
#  'loved',
#  'nj',
#  'finale',
#  'last',
#  'nite',
#  'wish',
#  'watched',
#  'nothing',
#  '69_4ever',
#  'time',
#  'like',
#  'million',
#  'know',
#  'ooh',
#  'post',
#  'yesterday',
#  'thank',
#  'you',
#  'xd',
#  'know',
#  'watch',
#  'counter',
#  'woe',
#  'love',
#  'fact',
#  'summer',
#  'already',
#  'however',
#  'love',
#  'melting',
#  'heat',
#  'hopefully',
#  'blog',
#  'post',
#  'help',
#  'frame',
#  'proper',
#  'context',
#  'using',
#  'effectively',
#  'like',
#  'pinata',
#  'beat',
#  'stick',
#  'find',
#  'jk',
#  'jk',
#  'xd',
#  'baby',
#  'bird',
#  'fell',
#  'nest',
#  'onto',
#  'patio',
#  'morning',
#  'even',
#  'get',
#  'chance',
#  'say',
#  'hello',
#  'mary',
#  'jane',
#  'birthday',
#  'okay',
#  'kate',
#  'moss',
#  'school',
#  'then',
#  '817',
#  '75mph',
#  'way',
#  'took',
#  'forever',
#  'get',
#  'friend',
#  'house',
#  'felt',
#  'like',
#  '10',
#  'minute',
#  'get',
#  'home',
#  'cant',
#  'fall',
#  'asleep',
#  'got',
#  'bbq',
#  'shopping',
#  'done',
#  'finished',
#  'email',
#  'argument',
#  'garden',
#  'reclaim',
#  'pond',
#  'chillout',
#  'bon',
#  'voyage',
#  'mstwinkie',
#  'may',
#  'transform',
#  'europe',
#  'crafty',
#  'wonderland',
#  'sad',
#  '_baldock',
#  'refuse',
#  'follow',
#  'despite',
#  'pleading',
#  'meanie',
#  'good',
#  'girl',
#  'omg',
#  'sims',
#  'yey',
#  '34768908547',
#  'hour',
#  'computer',
#  'soooo',
#  'tired',
#  'off',
#  'school',
#  'teach',
#  'kid',
#  'back',
#  'home',
#  'sleep',
#  'argh',
#  'ubuntu',
#  '904',
#  'taking',
#  'painfully',
#  'long',
#  'download',
#  'work',
#  'today',
#  '2',
#  'gonna',
#  'long',
#  'day',
#  'feel',
#  'lol',
#  'getting',
#  'know',
#  'twitter',
#  'drinking',
#  'refreshing',
#  'glass',
#  'pimms',
#  'sun',
#  'shining',
#  'would',
#  'great',
#  'day',
#  'golfing',
#  'bos',
#  'gone',
#  'work',
#  'instead',
#  'link',
#  'like',
#  'supposed',
#  'be',
#  'wow',
#  'okay',
#  'well',
#  'get',
#  'chance',
#  'jordan',
#  'give',
#  'momma',
#  'call',
#  'shed',
#  'love',
#  'thanks',
#  'lol',
#  'a',
#  'c',
#  'car',
#  '_a_michael',
#  'exciting',
#  'hope',
#  'get',
#  'set',
#  'soon',
#  'could',
#  'even',
#  'bubble',
#  'tweet',
#  'looooove',
#  'mcfly',
#  'video',
#  'myspace',
#  'wwwmyspacecomkat_04071991',
#  'go',
#  'watch',
#  'favourite',
#  'omg',
#  'cried',
#  'like',
#  '10th',
#  'time',
#  'ive',
#  'watched',
#  'it',
#  'wahhhh',
#  '2879',
#  'never',
#  'got',
#  'tour',
#  'lansing',
#  'fair',
#  'lol',
#  'know',
#  'feel',
#  'good',
#  'morning',
#  'world',
#  'wish',
#  'could',
#  'go',
#  'whitton',
#  'prom',
#  'wiv',
#  'mate',
#  'cant',
#  'longer',
#  'student',
#  'every',
#  '1',
#  'excited',
#  '4',
#  'cant',
#  'wait',
#  'ill',
#  'able',
#  'watch',
#  'last',
#  'song',
#  'probably',
#  'going',
#  'one',
#  'best',
#  'movie',
#  'ever',
#  'think',
#  'xd',
#  'love',
#  'trip',
#  'yesterday',
#  'ehhehe',
#  'beach',
#  'beach',
#  'swimming',
#  'frou',
#  'frou',
#  'let',
#  'go',
#  'fun',
#  'haha',
#  'finished',
#  'noodle',
#  'n',
#  'corn',
#  'n',
#  'pork',
#  'ham',
#  'right',
#  'im',
#  'still',
#  'jealousi',
#  'think',
#  'im',
#  'going',
#  'eating',
#  'anything',
#  'like',
#  'tomorrow',
#  'probably',
#  'salad',
#  'bad',
#  'mood',
#  'going',
#  'stay',
#  'away',
#  'everyone',
#  'today',
#  'developing',
#  'java',
#  'framework',
#  'thats',
#  'say',
#  'now',
#  'im',
#  'looking',
#  'forward',
#  'up',
#  'u',
#  'k',
#  'till',
#  'october',
#  'time',
#  'though',
#  'let',
#  'u',
#  'know',
#  'like',
#  'jusy',
#  'watched',
#  'from',
#  'within',
#  'pretty',
#  'good',
#  'b',
#  'rated',
#  'movie',
#  'exessive',
#  'christian',
#  'always',
#  'annoying',
#  'cut',
#  'grass',
#  '_congeniality',
#  'im',
#  'tired',
#  'it',
#  'crap',
#  'saw',
#  'yesterday',
#  'didnt',
#  'stay',
#  'end',
#  'credit',
#  'happend',
#  'nope',
#  'currently',
#  'hey',
#  'twit',
#  'there',
#  'article',
#  'bout',
#  'bgirll',
#  'magz',
#  'sorry',
#  'dang',
#  'camper',
#  'came',
#  'back',
#  'shut',
#  'laptop',
#  'left',
#  'opened',
#  'internet',
#  'dinner',
#  'rio',
#  'hoping',
#  'catch',
#  'glimpse',
#  'fave',
#  'chippendale',
#  'totally',
#  'see',
#  'inbox',
#  '272',
#  'there',
#  'anything',
#  'need',
#  'get',
#  'urgently',
#  'dm',
#  'me',
#  'waiting',
#  'ride',
#  'ohdee',
#  'hungry',
#  'want',
#  'play',
#  'sims',
#  'justin',
#  'jogging',
#  'computer',
#  'trackle',
#  'squarespace',
#  'cool',
#  'wish',
#  'would',
#  'stuck',
#  'ballet',
#  'cant',
#  'help',
#  'there',
#  'jr',
#  'urawazaless',
#  'think',
#  'last',
#  'day',
#  'ever',
#  'scooby',
#  'right',
#  'hand',
#  'hurt',
#  'playing',
#  'legato',
#  'staccato',
#  't_t',
#  'damn',
#  'cannot',
#  'playing',
#  'piano',
#  'w',
#  'two',
#  'hand',
#  'crest',
#  'white',
#  'strip',
#  'make',
#  'teeth',
#  'hurt',
#  'everyone',
#  'know',
#  'ready',
#  'work',
#  'sunshine',
#  'drop',
#  'flo',
#  'bus',
#  'stop',
#  'going',
#  'try',
#  'happy',
#  ...]

# %%
flat_words = ' '.join([i for i in df_train["tweet"]]).split()

word_freq = FreqDist(flat_words)

word_freq.most_common(30)
# Out:
# [('im', 9187),
#  ('day', 5314),
#  ('good', 4668),
#  ('get', 4367),
#  ('like', 3942),
#  ('go', 3909),
#  ('love', 3491),
#  ('u', 3455),
#  ('work', 3421),
#  ('today', 3345),
#  ('time', 3331),
#  ('going', 3193),
#  ('cant', 3164),
#  ('got', 3022),
#  ('lol', 3016),
#  ('back', 2858),
#  ('one', 2850),
#  ('know', 2778),
#  ('really', 2490),
#  ('want', 2431),
#  ('it', 2396),
#  ('night', 2323),
#  ('see', 2304),
#  ('well', 2284),
#  ('still', 2226),
#  ('think', 2223),
#  ('new', 2119),
#  ('2', 2078),
#  ('thanks', 2073),
#  ('home', 2029)]

# %%
from gensim.corpora import Dictionary

#create dictionary
text_dict = Dictionary([tweet.split() for tweet in df_train['tweet']])

#view integer mappings
text_dict.token2id
# Out:
# {'headache': 0,
#  'hope': 1,
#  'monster': 2,
#  'sleep': 3,
#  '2': 4,
#  'cry': 5,
#  'damn': 6,
#  'day': 7,
#  'fedex': 8,
#  'im': 9,
#  'laptop': 10,
#  'new': 11,
#  'number': 12,
#  'sad': 13,
#  'tracking': 14,
#  'working': 15,
#  '_crazy': 16,
#  'appliance': 17,
#  'beginning': 18,
#  'behind': 19,
#  'clean': 20,
#  'cleaning': 21,
#  'nest': 22,
#  'pull': 23,
#  'so': 24,
#  'think': 25,
#  'time': 26,
#  'w': 27,
#  'wanted': 28,
#  'good': 29,
#  'life': 30,
#  'morning': 31,
#  'outlook': 32,
#  'thing': 33,
#  'tweet': 34,
#  'cant': 35,
#  'flail': 36,
#  'january': 37,
#  'too': 38,
#  'yet': 39,
#  '90210': 40,
#  'austin': 41,
#  'brian': 42,
#  'green': 43,
#  'happened': 44,
#  'hott': 45,
#  'miss': 46,
#  'original': 47,
#  'whatever': 48,
#  'communication': 49,
#  'lack': 50,
#  'confident': 51,
#  'physic': 52,
#  'psych': 53,
#  'somehow': 54,
#  'felt': 55,
#  'island': 56,
#  'king': 57,
#  'today': 58,
#  'beleev': 59,
#  'fast': 60,
#  'foil': 61,
#  'gettin': 62,
#  'goin': 63,
#  'left': 64,
#  'love': 65,
#  'month': 66,
#  'on': 67,
#  'put': 68,
#  'bye': 69,
#  'caused': 70,
#  'inconv': 71,
#  'sorry': 72,
#  'srikanth': 73,
#  'tc': 74,
#  '09': 75,
#  'best': 76,
#  'imc': 77,
#  'residency': 78,
#  'summer': 79,
#  'wishing': 80,
#  '1': 81,
#  'again': 82,
#  'lol': 83,
#  'report': 84,
#  'start': 85,
#  'thursday': 86,
#  'whoohoooo': 87,
#  'laying': 88,
#  'sun': 89,
#  'line': 90,
#  'sure': 91,
#  'brace': 92,
#  'fudge': 93,
#  'get': 94,
#  'school': 95,
#  'cute': 96,
#  'haha': 97,
#  'macie': 98,
#  'done': 99,
#  'happy': 100,
#  'much': 101,
#  'omg': 102,
#  'same': 103,
#  'singing': 104,
#  'tired': 105,
#  'well': 106,
#  'collaborate': 107,
#  'see': 108,
#  'shall': 109,
#  'access': 110,
#  'everything': 111,
#  'exhausted': 112,
#  'fun': 113,
#  'light': 114,
#  'mostly': 115,
#  'outlet': 116,
#  'painting': 117,
#  'real': 118,
#  'room': 119,
#  'started': 120,
#  'taped': 121,
#  'tomorrow': 122,
#  'took': 123,
#  'unscrewed': 124,
#  'defective': 125,
#  'may': 126,
#  'phone': 127,
#  'possible': 128,
#  'aunt': 129,
#  'boring': 130,
#  'but': 131,
#  'chewauhah': 132,
#  'favorite': 133,
#  'gone': 134,
#  'how': 135,
#  'lena': 136,
#  'uncle': 137,
#  'cheese': 138,
#  'jos': 139,
#  'mac': 140,
#  'nom': 141,
#  'bill': 142,
#  'it': 143,
#  'lazy': 144,
#  'money': 145,
#  'pay': 146,
#  '178': 147,
#  'dang': 148,
#  'hamburger': 149,
#  'monday': 150,
#  'over': 151,
#  'party': 152,
#  'pound': 153,
#  'pushed': 154,
#  'trailer': 155,
#  'trash': 156,
#  'weighin': 157,
#  'yummy': 158,
#  'back': 159,
#  'cheating': 160,
#  'sry': 161,
#  'tweetie': 162,
#  'could': 163,
#  'feeling': 164,
#  'lukeys': 165,
#  'mom': 166,
#  'next': 167,
#  'sick': 168,
#  'u': 169,
#  'week': 170,
#  'wish': 171,
#  'yeah': 172,
#  'died': 173,
#  'instead': 174,
#  'kate': 175,
#  'hmm': 176,
#  'still': 177,
#  'twitteriffic': 178,
#  'background': 179,
#  'dont': 180,
#  'okay': 181,
#  'twitter': 182,
#  'upload': 183,
#  'reckon': 184,
#  'made': 185,
#  'miami': 186,
#  'tattoo': 187,
#  'yaay': 188,
#  'house': 189,
#  'locked': 190,
#  'outta': 191,
#  '1111': 192,
#  'problem': 193,
#  'thats': 194,
#  'barely': 195,
#  'business': 196,
#  'delayed': 197,
#  'find': 198,
#  'first': 199,
#  'flight': 200,
#  'layover': 201,
#  'phoenix': 202,
#  'seattle': 203,
#  'travel': 204,
#  'yay': 205,
#  'chicken': 206,
#  'cutlet': 207,
#  'ever': 208,
#  'beautiful': 209,
#  'family': 210,
#  'loving': 211,
#  'moment': 212,
#  'sharing': 213,
#  'special': 214,
#  'thanks': 215,
#  '7': 216,
#  'coffee': 217,
#  'drive': 218,
#  'fueled': 219,
#  'hazlenut': 220,
#  'home': 221,
#  'hr': 222,
#  'iced': 223,
#  'mcds': 224,
#  'w00t': 225,
#  'because': 226,
#  'bit': 227,
#  'empty': 228,
#  'going': 229,
#  'hall': 230,
#  'like': 231,
#  'little': 232,
#  'lot': 233,
#  'meant': 234,
#  'sort': 235,
#  'cloud': 236,
#  'did': 237,
#  'dust': 238,
#  'invisble': 239,
#  'peroson': 240,
#  'person': 241,
#  'simple': 242,
#  'superstar': 243,
#  'yo': 244,
#  '4christ': 245,
#  'goodapparently': 246,
#  'excited': 247,
#  'feel': 248,
#  'journey': 249,
#  'kind': 250,
#  'really': 251,
#  'strange': 252,
#  'surreal': 253,
#  'go': 254,
#  'letting': 255,
#  'now': 256,
#  'reason': 257,
#  'right': 258,
#  'youre': 259,
#  'alright': 260,
#  'everyone': 261,
#  'finally': 262,
#  'hit': 263,
#  'picked': 264,
#  'road': 265,
#  '25': 266,
#  'away': 267,
#  'brawwwwlin': 268,
#  'fro': 269,
#  'haaad': 270,
#  'if': 271,
#  'long': 272,
#  'night': 273,
#  'sat': 274,
#  'second': 275,
#  'steph': 276,
#  'there': 277,
#  'walked': 278,
#  'wed': 279,
#  '102': 280,
#  'chemistry': 281,
#  'nooo': 282,
#  'nothing': 283,
#  'ohhh': 284,
#  'one': 285,
#  'schoooool': 286,
#  'sleepp': 287,
#  'weekk': 288,
#  'another': 289,
#  'enjoy': 290,
#  'joy': 291,
#  'late': 292,
#  'skip': 293,
#  'congrats': 294,
#  'godbless': 295,
#  'bad': 296,
#  'help': 297,
#  'id': 298,
#  'know': 299,
#  'what': 300,
#  'balloon': 301,
#  'head': 302,
#  'ill': 303,
#  'nap': 304,
#  'pop': 305,
#  'productive': 306,
#  'promise': 307,
#  'take': 308,
#  'always': 309,
#  'cake': 310,
#  'google': 311,
#  'irel': 312,
#  'that': 313,
#  'walnut': 314,
#  'df': 315,
#  'dubb': 316,
#  'plane': 317,
#  'wait': 318,
#  'appreciated': 319,
#  '_eric': 320,
#  'draw': 321,
#  'grow': 322,
#  'least': 323,
#  'picture': 324,
#  'pretty': 325,
#  'since': 326,
#  'wanna': 327,
#  'you': 328,
#  'geek': 329,
#  'squad': 330,
#  'visit': 331,
#  'easy': 332,
#  'high': 333,
#  'live': 334,
#  'mighty': 335,
#  'righteously': 336,
#  'takin': 337,
#  'boyfriend': 338,
#  'sunday': 339,
#  'fall': 340,
#  'miki': 341,
#  'read': 342,
#  's': 343,
#  'soooo': 344,
#  'want': 345,
#  'writing': 346,
#  '13': 347,
#  'astronaut': 348,
#  'cassidy': 349,
#  'chris': 350,
#  'hometown': 351,
#  'i': 352,
#  'june': 353,
#  'maine': 354,
#  'nasa': 355,
#  'spaceshuttle': 356,
#  '1029': 357,
#  'concert': 358,
#  'missed': 359,
#  'becuz': 360,
#  'sigh': 361,
#  'stuff': 362,
#  'though': 363,
#  'trouble': 364,
#  'bored': 365,
#  'eva': 366,
#  'mad': 367,
#  'got': 368,
#  'lesson': 369,
#  'many': 370,
#  'season': 371,
#  'swim': 372,
#  'all': 373,
#  'better': 374,
#  'currently': 375,
#  'rained': 376,
#  'fault': 377,
#  'him': 378,
#  'ikr': 379,
#  'letter': 380,
#  'loooove': 381,
#  'make': 382,
#  'sha': 383,
#  'sooooo': 384,
#  'busy': 385,
#  'fine': 386,
#  'hi': 387,
#  'indeed': 388,
#  'not': 389,
#  'seem': 390,
#  'staci': 391,
#  'buy': 392,
#  'degree': 393,
#  'mngr': 394,
#  'moes': 395,
#  'position': 396,
#  'undergrad': 397,
#  '_tinks': 398,
#  'aha': 399,
#  'getting': 400,
#  'he': 401,
#  'jackson': 402,
#  'lucky': 403,
#  'ready': 404,
#  'rival': 405,
#  'whoa': 406,
#  'woken': 407,
#  'yes': 408,
#  'shit': 409,
#  'early': 410,
#  'up': 411,
#  '4': 412,
#  'b96': 413,
#  'bash': 414,
#  'chitown': 415,
#  'finalist': 416,
#  'please': 417,
#  'vote': 418,
#  'effing': 419,
#  'finale': 420,
#  'j': 421,
#  'k': 422,
#  'last': 423,
#  'loved': 424,
#  'meerning': 425,
#  'nite': 426,
#  'nj': 427,
#  'thanx': 428,
#  'watched': 429,
#  '69_4ever': 430,
#  'million': 431,
#  'counter': 432,
#  'ooh': 433,
#  'post': 434,
#  'thank': 435,
#  'watch': 436,
#  'woe': 437,
#  'xd': 438,
#  'yesterday': 439,
#  'already': 440,
#  'fact': 441,
#  'heat': 442,
#  'however': 443,
#  'melting': 444,
#  'blog': 445,
#  'context': 446,
#  'effectively': 447,
#  'frame': 448,
#  'hopefully': 449,
#  'proper': 450,
#  'using': 451,
#  'beat': 452,
#  'jk': 453,
#  'pinata': 454,
#  'stick': 455,
#  'baby': 456,
#  'bird': 457,
#  'birthday': 458,
#  'chance': 459,
#  'even': 460,
#  'fell': 461,
#  'hello': 462,
#  'jane': 463,
#  'mary': 464,
#  'onto': 465,
#  'patio': 466,
#  'say': 467,
#  'moss': 468,
#  'then': 469,
#  '10': 470,
#  '75mph': 471,
#  '817': 472,
#  'forever': 473,
#  'friend': 474,
#  'minute': 475,
#  'way': 476,
#  'asleep': 477,
#  'argument': 478,
#  'bbq': 479,
#  'chillout': 480,
#  'email': 481,
#  'finished': 482,
#  'garden': 483,
#  'pond': 484,
#  'reclaim': 485,
#  'shopping': 486,
#  'bon': 487,
#  'crafty': 488,
#  'europe': 489,
#  'mstwinkie': 490,
#  'transform': 491,
#  'voyage': 492,
#  'wonderland': 493,
#  '_baldock': 494,
#  'despite': 495,
#  'follow': 496,
#  'meanie': 497,
#  'pleading': 498,
#  'refuse': 499,
#  'girl': 500,
#  '34768908547': 501,
#  'computer': 502,
#  'hour': 503,
#  'sims': 504,
#  'yey': 505,
#  'kid': 506,
#  'off': 507,
#  'teach': 508,
#  '904': 509,
#  'argh': 510,
#  'download': 511,
#  'painfully': 512,
#  'taking': 513,
#  'ubuntu': 514,
#  'gonna': 515,
#  'work': 516,
#  'drinking': 517,
#  'glass': 518,
#  'pimms': 519,
#  'refreshing': 520,
#  'be': 521,
#  'bos': 522,
#  'golfing': 523,
#  'great': 524,
#  'link': 525,
#  'shining': 526,
#  'supposed': 527,
#  'would': 528,
#  'call': 529,
#  'give': 530,
#  'jordan': 531,
#  'momma': 532,
#  'shed': 533,
#  'wow': 534,
#  'a': 535,
#  'c': 536,
#  'car': 537,
#  '_a_michael': 538,
#  'bubble': 539,
#  'exciting': 540,
#  'set': 541,
#  'soon': 542,
#  'favourite': 543,
#  'looooove': 544,
#  'mcfly': 545,
#  'myspace': 546,
#  'video': 547,
#  'wwwmyspacecomkat_04071991': 548,
#  '10th': 549,
#  'cried': 550,
#  'ive': 551,
#  'wahhhh': 552,
#  '2879': 553,
#  'fair': 554,
#  'lansing': 555,
#  'never': 556,
#  'tour': 557,
#  'world': 558,
#  'every': 559,
#  'longer': 560,
#  'mate': 561,
#  'prom': 562,
#  'student': 563,
#  'whitton': 564,
#  'wiv': 565,
#  'able': 566,
#  'movie': 567,
#  'probably': 568,
#  'song': 569,
#  'beach': 570,
#  'ehhehe': 571,
#  'swimming': 572,
#  'trip': 573,
#  'frou': 574,
#  'let': 575,
#  'corn': 576,
#  'ham': 577,
#  'n': 578,
#  'noodle': 579,
#  'pork': 580,
#  'anything': 581,
#  'eating': 582,
#  'jealousi': 583,
#  'salad': 584,
#  'mood': 585,
#  'stay': 586,
#  'developing': 587,
#  'framework': 588,
#  'java': 589,
#  'forward': 590,
#  'looking': 591,
#  'october': 592,
#  'till': 593,
#  'annoying': 594,
#  'b': 595,
#  'christian': 596,
#  'cut': 597,
#  'exessive': 598,
#  'from': 599,
#  'grass': 600,
#  'jusy': 601,
#  'rated': 602,
#  'within': 603,
#  '_congeniality': 604,
#  'crap': 605,
#  'credit': 606,
#  'didnt': 607,
#  'end': 608,
#  'happend': 609,
#  'nope': 610,
#  'saw': 611,
#  'article': 612,
#  'bgirll': 613,
#  'bout': 614,
#  'hey': 615,
#  'magz': 616,
#  'twit': 617,
#  'came': 618,
#  'camper': 619,
#  'dinner': 620,
#  'internet': 621,
#  'opened': 622,
#  'shut': 623,
#  'catch': 624,
#  'chippendale': 625,
#  'fave': 626,
#  'glimpse': 627,
#  'hoping': 628,
#  'rio': 629,
#  'totally': 630,
#  '272': 631,
#  'dm': 632,
#  'inbox': 633,
#  'me': 634,
#  'need': 635,
#  'urgently': 636,
#  'hungry': 637,
#  'ohdee': 638,
#  'ride': 639,
#  'waiting': 640,
#  'jogging': 641,
#  'justin': 642,
#  'play': 643,
#  'squarespace': 644,
#  'trackle': 645,
#  'ballet': 646,
#  'cool': 647,
#  'stuck': 648,
#  'jr': 649,
#  'urawazaless': 650,
#  'scooby': 651,
#  'cannot': 652,
#  'hand': 653,
#  'hurt': 654,
#  'legato': 655,
#  'piano': 656,
#  'playing': 657,
#  'staccato': 658,
#  't_t': 659,
#  'two': 660,
#  'crest': 661,
#  'strip': 662,
#  'teeth': 663,
#  'white': 664,
#  'bus': 665,
#  'drop': 666,
#  'flo': 667,
#  'stop': 668,
#  'sunshine': 669,
#  'try': 670,
#  'caroline': 671,
#  'maureen': 672,
#  'mother': 673,
#  'whatchu': 674,
#  'hmmm': 675,
#  'worse': 676,
#  'luck': 677,
#  'lady': 678,
#  'old': 679,
#  'tweeeps': 680,
#  'â': 681,
#  'dad': 682,
#  'holiday': 683,
#  'competitive': 684,
#  'effectiveness': 685,
#  'hot': 686,
#  'teacher': 687,
#  'mean': 688,
#  'chie': 689,
#  'loh': 690,
#  'maag': 691,
#  'makan': 692,
#  'nanti': 693,
#  'siang': 694,
#  'surely': 695,
#  'ya': 696,
#  'fed': 697,
#  'packing': 698,
#  'exam': 699,
#  'revising': 700,
#  'gym': 701,
#  'shoe': 702,
#  'ugh': 703,
#  'without': 704,
#  '3': 705,
#  'blackberry': 706,
#  'dumb': 707,
#  'gotta': 708,
#  'leg': 709,
#  'update': 710,
#  'year': 711,
#  'burnt': 712,
#  'cream': 713,
#  'forgot': 714,
#  'ouch': 715,
#  'woops': 716,
#  'happens': 717,
#  'md': 718,
#  'brain': 719,
#  'especially': 720,
#  'neds': 721,
#  'nice': 722,
#  'portpatrick': 723,
#  'shame': 724,
#  'stereo': 725,
#  'who': 726,
#  'strenght': 727,
#  'been': 728,
#  'falafel': 729,
#  'nyc': 730,
#  'tiam': 731,
#  'village': 732,
#  'included': 733,
#  'longest': 734,
#  'poem': 735,
#  'wwwlongestpoemintheworldcomtweet15638': 736,
#  'later': 737,
#  'run': 738,
#  'chad': 739,
#  'rough': 740,
#  'alll': 741,
#  'eye': 742,
#  'open': 743,
#  'ago': 744,
#  'coming': 745,
#  'woke': 746,
#  'dance': 747,
#  '20': 748,
#  'ambien': 749,
#  'bowl': 750,
#  'comatose': 751,
#  'luckycharms': 752,
#  'milk': 753,
#  'reesespuffs': 754,
#  '5': 755,
#  'aww': 756,
#  '3000': 757,
#  'as': 758,
#  'cause': 759,
#  'come': 760,
#  'dammit': 761,
#  'down': 762,
#  'slow': 763,
#  'dick': 764,
#  'name': 765,
#  'ah': 766,
#  'amazing': 767,
#  'awh': 768,
#  'voice': 769,
#  'babe': 770,
#  'comedy': 771,
#  'definitely': 772,
#  'maybe': 773,
#  'stalking': 774,
#  'type': 775,
#  'wig': 776,
#  '30': 777,
#  'bike': 778,
#  'crashed': 779,
#  'emergency': 780,
#  'mph': 781,
#  'shoulder': 782,
#  'connection': 783,
#  'guy': 784,
#  'turned': 785,
#  'dog': 786,
#  'flat': 787,
#  'highway': 788,
#  'my': 789,
#  'side': 790,
#  'tire': 791,
#  '21': 792,
#  'course': 793,
#  'delay': 794,
#  'gah': 795,
#  'plan': 796,
#  'heard': 797,
#  'romantic': 798,
#  'word': 799,
#  '100': 800,
#  'add': 801,
#  'follower': 802,
#  'train': 803,
#  'vip': 804,
#  'wwwtweeterfollowcom': 805,
#  'doctor': 806,
#  '_ising': 807,
#  'ahahah': 808,
#  'reminding': 809,
#  'english': 810,
#  'learn': 811,
#  'test': 812,
#  '76': 813,
#  'aint': 814,
#  'mel': 815,
#  'are': 816,
#  'hahah': 817,
#  'tom': 818,
#  'window': 819,
#  'art': 820,
#  'meditating': 821,
#  'praying': 822,
#  'hannah': 823,
#  'montana': 824,
#  'watching': 825,
#  'finish': 826,
#  'handle': 827,
#  'havent': 828,
#  'india': 829,
#  'leaf': 830,
#  '11': 831,
#  'courney': 832,
#  'cox': 833,
#  'dream': 834,
#  'lakers': 835,
#  'losing': 836,
#  'mohawk': 837,
#  'worst': 838,
#  'wtf': 839,
#  'zip': 840,
#  'check': 841,
#  'park': 842,
#  'stream': 843,
#  'taylor': 844,
#  'ur': 845,
#  'vid': 846,
#  '1993': 847,
#  'confirmation': 848,
#  'do': 849,
#  'excellent': 850,
#  'found': 851,
#  'predicted': 852,
#  'site': 853,
#  'wicked': 854,
#  'bite': 855,
#  'hiney': 856,
#  'immature': 857,
#  'people': 858,
#  'stupid': 859,
#  'wit': 860,
#  'dress': 861,
#  'grad': 862,
#  'hannahs': 863,
#  '418': 864,
#  'awesome': 865,
#  'bump': 866,
#  'catho': 867,
#  'ctown': 868,
#  'far': 869,
#  'gong': 870,
#  'might': 871,
#  'iranelection': 872,
#  'jp': 873,
#  'lmfao': 874,
#  'trying': 875,
#  'newmoon': 876,
#  'facebooking': 877,
#  'hmmhm': 878,
#  'ima': 879,
#  'm': 880,
#  'major': 881,
#  'nickelodeon': 882,
#  'o': 883,
#  'p': 884,
#  'shower': 885,
#  'bootleg': 886,
#  'copy': 887,
#  'ol': 888,
#  'origin': 889,
#  'porn': 890,
#  'q': 891,
#  'sadly': 892,
#  'swedish': 893,
#  'wolverine': 894,
#  'xmen': 895,
#  'blondies': 896,
#  '1033': 897,
#  '3rd': 898,
#  'future': 899,
#  'hehe': 900,
#  'pm': 901,
#  'farrah': 902,
#  'fawcett': 903,
#  'passed': 904,
#  'story': 905,
#  'childhood': 906,
#  'allergy': 907,
#  'begun': 908,
#  'urgh': 909,
#  '31': 910,
#  'august': 911,
#  'cliffhanger': 912,
#  'emotional': 913,
#  'greek': 914,
#  'understated': 915,
#  '4afterwebradio': 916,
#  'bluebeard': 917,
#  'castle': 918,
#  'clever': 919,
#  'operaplot': 920,
#  'super': 921,
#  'francisco': 922,
#  'lion': 923,
#  'san': 924,
#  'sea': 925,
#  'blown': 926,
#  'choice': 927,
#  'cocktail': 928,
#  'occassions': 929,
#  'rarely': 930,
#  'sleeping': 931,
#  'wake': 932,
#  'weapon': 933,
#  'black': 934,
#  'checking': 935,
#  'fit': 936,
#  'sequin': 937,
#  'weekend': 938,
#  '_detlor': 939,
#  '2207': 940,
#  'hug': 941,
#  'math': 942,
#  'movemnts': 943,
#  'naawww': 944,
#  'oh': 945,
#  'rape': 946,
#  'rule': 947,
#  'sudden': 948,
#  'twitted': 949,
#  'la': 950,
#  'myself': 951,
#  'something': 952,
#  'wana': 953,
#  'butterfly': 954,
#  'eventually': 955,
#  'killed': 956,
#  'lie': 957,
#  'pathetic': 958,
#  'tear': 959,
#  'enjoying': 960,
#  'layin': 961,
#  'pool': 962,
#  'full': 963,
#  'sooooooo': 964,
#  'sooooooooooooooooooooooooooooooooooooo': 965,
#  'burp': 966,
#  'delicious': 967,
#  'xx': 968,
#  'heart': 969,
#  'kingdom': 970,
#  'normal': 971,
#  'ouuu': 972,
#  'psp': 973,
#  'aswell': 974,
#  'fool': 975,
#  '3pm': 976,
#  'bottle': 977,
#  'company': 978,
#  'hangover': 979,
#  'toast': 980,
#  'vodka': 981,
#  'waking': 982,
#  'dying': 983,
#  'faycett': 984,
#  'hear': 985,
#  'kl': 986,
#  'funny': 987,
#  'sign': 988,
#  'thought': 989,
#  'fixed': 990,
#  'cooking': 991,
#  'tomora': 992,
#  'hold': 993,
#  'strong': 994,
#  'weak': 995,
#  '_shinegurl': 996,
#  'lawn': 997,
#  'look': 998,
#  'mowed': 999,
#  ...}

# %%
tweets_bow = [text_dict.doc2bow(tweet.split()) for tweet in df_train['tweet']]

# %%
from gensim.models.ldamodel import LdaModel

k = 5
tweets_lda = LdaModel(tweets_bow,
                      num_topics = k,
                      id2word = text_dict,
                      random_state = 1,
                      passes=10)

tweets_lda.show_topics()
# Out:
# [(0,
#   '0.012*"want" + 0.010*"like" + 0.009*"movie" + 0.009*"wanna" + 0.009*"go" + 0.009*"watching" + 0.008*"cant" + 0.007*"need" + 0.006*"sound" + 0.006*"out"'),
#  (1,
#   '0.030*"day" + 0.026*"good" + 0.021*"im" + 0.019*"today" + 0.019*"work" + 0.014*"going" + 0.013*"night" + 0.013*"go" + 0.012*"time" + 0.012*"home"'),
#  (2,
#   '0.027*"im" + 0.017*"love" + 0.017*"u" + 0.014*"know" + 0.013*"lol" + 0.013*"like" + 0.011*"cant" + 0.010*"it" + 0.008*"get" + 0.008*"thats"'),
#  (3,
#   '0.009*"twitter" + 0.009*"yes" + 0.009*"thank" + 0.008*"oh" + 0.008*"new" + 0.007*"got" + 0.006*"still" + 0.006*"lol" + 0.006*"no" + 0.006*"please"'),
#  (4,
#   '0.010*"thanks" + 0.009*"trying" + 0.008*"ð" + 0.006*"head" + 0.006*"food" + 0.006*"cry" + 0.006*"½" + 0.005*"face" + 0.005*"follower" + 0.005*"s"')]

# %%
print(tweets_lda.print_topics())
doc_lda = tweets_lda[tweets_bow]
# Out:
# [(0, '0.012*"want" + 0.010*"like" + 0.009*"movie" + 0.009*"wanna" + 0.009*"go" + 0.009*"watching" + 0.008*"cant" + 0.007*"need" + 0.006*"sound" + 0.006*"out"'), (1, '0.030*"day" + 0.026*"good" + 0.021*"im" + 0.019*"today" + 0.019*"work" + 0.014*"going" + 0.013*"night" + 0.013*"go" + 0.012*"time" + 0.012*"home"'), (2, '0.027*"im" + 0.017*"love" + 0.017*"u" + 0.014*"know" + 0.013*"lol" + 0.013*"like" + 0.011*"cant" + 0.010*"it" + 0.008*"get" + 0.008*"thats"'), (3, '0.009*"twitter" + 0.009*"yes" + 0.009*"thank" + 0.008*"oh" + 0.008*"new" + 0.007*"got" + 0.006*"still" + 0.006*"lol" + 0.006*"no" + 0.006*"please"'), (4, '0.010*"thanks" + 0.009*"trying" + 0.008*"ð" + 0.006*"head" + 0.006*"food" + 0.006*"cry" + 0.006*"½" + 0.005*"face" + 0.005*"follower" + 0.005*"s"')]
# /Users/alberttamman/opt/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from pyLDAvis import gensim, display
# Out:
# /Users/alberttamman/opt/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pyLDAvis.enable_notebook(local = True)

vis = pyLDAvis.gensim.prepare(tweets_lda, tweets_bow, dictionary=tweets_lda.id2word)
# Out:
# /Users/alberttamman/opt/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
vis
# Out:
# /Users/alberttamman/opt/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2      0.174566  0.011128       1        1  31.121798
# 1      0.158001 -0.185769       2        1  27.208582
# 3     -0.006915  0.294374       3        1  15.612799
# 0      0.036979 -0.034969       4        1  14.875358
# 4     -0.362631 -0.084763       5        1  11.181464, topic_info=      Term         Freq        Total Category  logprob  loglift
# 7      day  5139.000000  5139.000000  Default  30.0000  30.0000
# 29    good  4407.000000  4407.000000  Default  29.0000  29.0000
# 9       im  8765.000000  8765.000000  Default  28.0000  28.0000
# 58   today  3200.000000  3200.000000  Default  27.0000  27.0000
# 516   work  3159.000000  3159.000000  Default  26.0000  26.0000
# ..     ...          ...          ...      ...      ...      ...
# 343      s   319.748521   636.493868   Topic5  -5.3716   1.5025
# 884      p   271.477889   449.665807   Topic5  -5.5353   1.6863
# 578      n   254.523625   574.661836   Topic5  -5.5998   1.3765
# 94     get   315.656329  4076.602421   Topic5  -5.3845  -0.3675
# 352      i   256.410142  1364.150342   Topic5  -5.5924   0.5194
#
# [276 rows x 6 columns], token_table=       Topic      Freq Term
# term
# 81         1  0.301033    1
# 81         2  0.289164    1
# 81         3  0.410009    1
# 800        5  0.997046  100
# 3326       3  0.995898   12
# ...      ...       ...  ...
# 1168       5  0.998468    ½
# 21154      5  0.998462    à
# 681        5  0.998913    â
# 6838       5  0.998340    ð
# 6843       5  0.997559    ñ
#
# [342 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 2, 4, 1, 5])
